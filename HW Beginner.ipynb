# %%
# Task 1
"""
найти количество вхождений шаблона "хорош" в строке
вывести все уникальные слова в виде списка или строка длинной больше 5
заменить все слова, имеющие шаблон "хорош" на "схож"
примечание - необходимо перед работой со строкой очистить ее от всех ненужных и лишних символов
"""

string = 'Погода сегодня ХоРошая. То ли хорОШа ХОрошесть, то ли \n\n\n\n\t\t\t.       Хорошо от того, что хорошо:'\
'то ли сегодня хорошо, то ли в погода хорошая !/// ((( ,,, .от того, что жизнь хорошая'

# %%
# Task 2
"""
Даны названия трех городов. Напишите программу, которая определяет самое короткое и самое длинное название города.
""""
x=input()
x1=input()
x2=input()

# %%
# Task 3
"""
Напишите программу, которая считывает одну строку, после чего выводит «YES», 
если в введённой строке есть подстрока «суббота» или «воскресенье», и «NO» в противном случае.
"""
x=input() # Введите произвольное предложение

# %%
# Task 4
"""
Будем считать email адрес корректным, если в нем есть символ собачки (@) и точки. 
Напишите программу проверяющую корректность email адреса.
"""
x=input()# Введите произвольное email

# %%
# Task 5
"""
На вход программе подается одна строка. 
Напишите программу, которая выводит элементы строки с индексами 0, 2, 4, ... в столбик.
"""
s=input() # Введите произвольное предложение

# %%
# Task 6
"""
Переверните строка так, чтобы последний индекс стал первым и наоборот
Пример: привет ---> тевирп
"""
string = input()# Введите произвольное слово

# %%
# Task 7
"""
На вход программе подается одна строка. 
Напишите программу, которая определяет сколько в ней одинаковых соседних символов.

Пример: у строки aaccd 2 одинаковых соседей, у строки qassd - 1, у жжуужжуу - 4
"""
string = input()

# %%
# Task 8
"""
Необходимо найти все корректные номера в строке
Примечание - номера можно вывести в ответ без тире
"""
string = '8-900-456-56-56, 8-567-45-34, 8-4534626-45645-465-45, 8-900-fff-443, привет'
